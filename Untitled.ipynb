# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import datetime as dt
import matplotlib.pyplot as plt

# %%
Weatherdata=pd.read_csv("Summary of Weather.csv")
StationDet=pd.read_csv("Weather Station Locations.csv")

# %%
Weatherdata=pd.read_csv("Summary of Weather.csv")
StationDet=pd.read_csv("Weather Station Locations.csv")

# %%
Weatherdata.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  SD3  RHX  RHN  \
# 0      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 1      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 2      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 3      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 4      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
#
#   RVG  WTE
# 0 NaN  NaN
# 1 NaN  NaN
# 2 NaN  NaN
# 3 NaN  NaN
# ...

# %%
Weatherdata.isnull().sum()
# Out:
# STA                 0
# Date                0
# Precip              0
# WindGustSpd    118508
# MaxTemp             0
# MinTemp             0
# MeanTemp            0
# Snowfall         1163
# PoorWeather     84803
# YR                  0
# MO                  0
# DA                  0
# PRCP             1932
# DR             118507
# SPD            118508
# MAX               474
# MIN               468
# MEA               498
# SNF              1163
# SND            113477
# FT             119040
# FB             119040
# FTI            119040
# ITH            119040
# PGT            118515
# TSHDSBRSGF      84803
# SD3            119040
# RHX            119040
# RHN            119040
# RVG            119040
# WTE            119040
# dtype: int64

# %%
Weatherdata.dropna(thresh=117000,axis=1,inplace=True)
Weatherdata.isnull().sum()
# Out:
# STA            0
# Date           0
# Precip         0
# MaxTemp        0
# MinTemp        0
# MeanTemp       0
# Snowfall    1163
# YR             0
# MO             0
# DA             0
# PRCP        1932
# MAX          474
# MIN          468
# MEA          498
# SNF         1163
# dtype: int64

# %%
Weatherdata.fillna(method='ffill',inplace=True)
Weatherdata.isnull().sum()
# Out:
# STA         0
# Date        0
# Precip      0
# MaxTemp     0
# MinTemp     0
# MeanTemp    0
# Snowfall    0
# YR          0
# MO          0
# DA          0
# PRCP        0
# MAX         0
# MIN         0
# MEA         0
# SNF         0
# dtype: int64

# %%
Weatherdata.head()
# Out:
#      STA      Date Precip    MaxTemp    MinTemp   MeanTemp Snowfall  YR  MO  \
# 0  10001  1942-7-1  1.016  25.555556  22.222222  23.888889      0.0  42   7
# 1  10001  1942-7-2      0  28.888889  21.666667  25.555556      0.0  42   7
# 2  10001  1942-7-3   2.54  26.111111  22.222222  24.444444      0.0  42   7
# 3  10001  1942-7-4   2.54  26.666667  22.222222  24.444444      0.0  42   7
# 4  10001  1942-7-5      0  26.666667  21.666667  24.444444      0.0  42   7
#
#    DA  PRCP   MAX   MIN   MEA  SNF
# 0   1  0.04  78.0  72.0  75.0  0.0
# 1   2     0  84.0  71.0  78.0  0.0
# 2   3   0.1  79.0  72.0  76.0  0.0
# 3   4   0.1  80.0  72.0  76.0  0.0
# 4   5     0  80.0  71.0  76.0  0.0

# %%
Weatherdata.dtypes
# Out:
# STA           int64
# Date         object
# Precip       object
# MaxTemp     float64
# MinTemp     float64
# MeanTemp    float64
# Snowfall     object
# YR            int64
# MO            int64
# DA            int64
# PRCP         object
# MAX         float64
# MIN         float64
# MEA         float64
# SNF          object
# dtype: object

# %%
Weatherdata['Date']=pd.to_datetime(Weatherdata['Date'])
Weatherdata.dtypes
# Out:
# STA                  int64
# Date        datetime64[ns]
# Precip              object
# MaxTemp            float64
# MinTemp            float64
# MeanTemp           float64
# Snowfall            object
# YR                   int64
# MO                   int64
# DA                   int64
# PRCP                object
# MAX                float64
# MIN                float64
# MEA                float64
# SNF                 object
# dtype: object

# %%
Weatherdata['Year']=Weatherdata['Date'].dt.year
Weatherdata['Month']=Weatherdata['Date'].dt.month

# %%
Weatherdata.head()
# Out:
#      STA       Date Precip    MaxTemp    MinTemp   MeanTemp Snowfall  YR  MO  \
# 0  10001 1942-07-01  1.016  25.555556  22.222222  23.888889      0.0  42   7
# 1  10001 1942-07-02      0  28.888889  21.666667  25.555556      0.0  42   7
# 2  10001 1942-07-03   2.54  26.111111  22.222222  24.444444      0.0  42   7
# 3  10001 1942-07-04   2.54  26.666667  22.222222  24.444444      0.0  42   7
# 4  10001 1942-07-05      0  26.666667  21.666667  24.444444      0.0  42   7
#
#    DA  PRCP   MAX   MIN   MEA  SNF  Year  Month
# 0   1  0.04  78.0  72.0  75.0  0.0  1942      7
# 1   2     0  84.0  71.0  78.0  0.0  1942      7
# 2   3   0.1  79.0  72.0  76.0  0.0  1942      7
# 3   4   0.1  80.0  72.0  76.0  0.0  1942      7
# 4   5     0  80.0  71.0  76.0  0.0  1942      7

# %%
StationDet
# Out:
#       WBAN            NAME STATE/COUNTRY ID    LAT     LON  ELEV   Latitude  \
# 0    33013          AIN EL               AL  3623N  00637E   611  36.383333
# 1    33031        LA SENIA               AL  3537N  00037E    88  35.616667
# 2    33023  MAISON BLANCHE               AL  3643N  00314E    23  36.716667
# 3    33044        TELERGMA               AL  3607N  00621E   754  36.116667
# 4    12001         TINDOUF               AL  2741N  00809W   443  27.683333
# ..     ...             ...              ...    ...     ...   ...        ...
# 156  33109       EL AQUINA               TS  3651N  01015E     4  36.850000
# 157  33121         EL DJEM               TS  3520N  01040E  9999  35.333333
# 158  33003      SISI AHMED               TS  3712N  00950E     4  37.200000
# 159  33307           ADANA               TU  3659N  03518E    20  36.983333
# 160  15027      WARRINGTON               UK  5323N  00239W    27  53.383333
#
#      Longitude
# 0     6.650000
# 1     0.583333
# ...

# %%
Alldata=pd.merge(Weatherdata,StationDet,left_on='STA',right_on='WBAN')
Alldata.head()
# Out:
#      STA       Date Precip    MaxTemp    MinTemp   MeanTemp Snowfall  YR  MO  \
# 0  10001 1942-07-01  1.016  25.555556  22.222222  23.888889      0.0  42   7
# 1  10001 1942-07-02      0  28.888889  21.666667  25.555556      0.0  42   7
# 2  10001 1942-07-03   2.54  26.111111  22.222222  24.444444      0.0  42   7
# 3  10001 1942-07-04   2.54  26.666667  22.222222  24.444444      0.0  42   7
# 4  10001 1942-07-05      0  26.666667  21.666667  24.444444      0.0  42   7
#
#    DA  ...  Year  Month   WBAN   NAME STATE/COUNTRY ID    LAT     LON  ELEV  \
# 0   1  ...  1942      7  10001  ACCRA               GH  0536N  00010W    62
# 1   2  ...  1942      7  10001  ACCRA               GH  0536N  00010W    62
# 2   3  ...  1942      7  10001  ACCRA               GH  0536N  00010W    62
# 3   4  ...  1942      7  10001  ACCRA               GH  0536N  00010W    62
# 4   5  ...  1942      7  10001  ACCRA               GH  0536N  00010W    62
#
#   Latitude Longitude
# 0      5.6      -0.3
# ...

# %%
Weatherdata.shape
# Out:
# (119040, 17)

# %%
Alldata.shape
# Out:
# (119040, 25)

# %%
Alldata.isnull().sum()
# Out:
# STA                 0
# Date                0
# Precip              0
# MaxTemp             0
# MinTemp             0
# MeanTemp            0
# Snowfall            0
# YR                  0
# MO                  0
# DA                  0
# PRCP                0
# MAX                 0
# MIN                 0
# MEA                 0
# SNF                 0
# Year                0
# Month               0
# WBAN                0
# NAME                0
# STATE/COUNTRY ID    0
# LAT                 0
# LON                 0
# ELEV                0
# Latitude            0
# Longitude           0
# dtype: int64

# %%
Alldata["STATE/COUNTRY ID"].nunique()
# Out:
# 63

# %%
Alldata["NAME"].nunique()
# Out:
# 157

# %%
Alldata
# Out:
#           STA       Date Precip    MaxTemp    MinTemp   MeanTemp Snowfall  YR  \
# 0       10001 1942-07-01  1.016  25.555556  22.222222  23.888889      0.0  42
# 1       10001 1942-07-02      0  28.888889  21.666667  25.555556      0.0  42
# 2       10001 1942-07-03   2.54  26.111111  22.222222  24.444444      0.0  42
# 3       10001 1942-07-04   2.54  26.666667  22.222222  24.444444      0.0  42
# 4       10001 1942-07-05      0  26.666667  21.666667  24.444444      0.0  42
# ...       ...        ...    ...        ...        ...        ...      ...  ..
# 119035  82506 1945-12-27      0  28.333333  18.333333  23.333333      0.0  45
# 119036  82506 1945-12-28  9.906  29.444444  18.333333  23.888889      0.0  45
# 119037  82506 1945-12-29      0  28.333333  18.333333  23.333333      0.0  45
# 119038  82506 1945-12-30      0  28.333333  18.333333  23.333333      0.0  45
# 119039  82506 1945-12-31      0  29.444444  17.222222  23.333333      0.0  45
#
# ...

# %%
Alldata.replace('T',0,inplace=True)

# %%
plt.plot(Alldata.groupby('Year')['MeanTemp','MaxTemp','MinTemp'].mean())
